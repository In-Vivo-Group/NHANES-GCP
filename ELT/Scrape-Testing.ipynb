# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import datetime
import time
from urllib.parse import urlparse
from utils import update_bq_table, generate_filename, upload_blob_from_string, scrape_nhanes_table
bucket_name = 'nhanes'

# %%
# df = pd.read_gbq("SELECT * FROM nhanes.nhanes_file_metadata",
#         project_id="nhanes-genai",
#         dialect="standard")

# %%
# df

# %%
# def scrape_nhanes_table(soup, component):
#     table = soup.find('table',id='GridView1')

#     headers = []
#     for i in table.find_all('th'):
#         title = i.text
#         headers.append(title)

#     base_url = "https://wwwn.cdc.gov"

#     data = []

#     for j in table.find_all('tr')[1:]:
#         row_data = j.find_all('td')
#         row = [i.text for i in row_data] + [base_url + i.a['href'] for i in row_data if i.find('a')]
#         data.append(row)
    
#     if len(data[0]) == len(headers) + 2:
#         headers = ['_'.join(h.lower().split()) for h in headers] + ['doc_file_url','data_file_url']
#     elif len(data[0]) == len(headers) + 1:
#         headers = ['_'.join(h.lower().split()) for h in headers] + ['doc_file_url']
#     else:
#         headers = ['_'.join(h.lower().split()) for h in headers]

#     df = pd.DataFrame(columns = headers,data=data)
    
#     return df

# %% [markdown]
# ### Scrape Continuous NHANES

# %%
dfs = []

components = ["Demographics","Dietary","Examination","Laboratory","Questionnaire","LimitedAccess"]

for component in components: 
    r = requests.get(f"https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component={component}")

    soup = BeautifulSoup(r.text, 'lxml')

    table = soup.find('table',id='GridView1')

    headers = []
    for i in table.find_all('th'):
        title = i.text
        headers.append(title)
    
    if component != 'LimitedAccess':
        headers = ['_'.join(h.lower().split()) for h in headers] + ['doc_file_url','data_file_url']
    else:
        headers = ['_'.join(h.lower().split()) for h in headers] + ['doc_file_url']

    base_url = "https://wwwn.cdc.gov"

    data = []

    for j in table.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [i.text for i in row_data] + [base_url + i.a['href'] for i in row_data if i.find('a')]
        data.append(row)

    df = pd.DataFrame(columns = headers,data=data)

    df['years'] = df['years'].str.strip()
    df['doc_file'] = df['doc_file'].str.strip()
    df['data_file'] = df['data_file'].str.strip()
    df['date_published'] = df['date_published'].str.strip().str.replace('Updated ','')
    df['start_year'] = df['years'].apply(lambda x: x.split('-')[0]).astype(int)
    df['end_year'] = df['years'].apply(lambda x: x.split('-')[1]).astype(int)
    df['published_date'] = pd.to_datetime(df['date_published'],format='%B %Y',errors='ignore')
    df['page_component'] = component
    df['last_updated'] = datetime.datetime.utcnow()
    df['gcs_doc_filename'] = (f'gs://{bucket_name}/docs/' + df['data_file_name'] + ' ' + df['start_year'].astype(str) + ' ' + df['end_year'].astype(str) + ' Documentation').apply(lambda x: generate_filename(x,extension='.html'))
    df['gcs_data_filename'] = (f'gs://{bucket_name}/data/' +df['data_file_name'] + ' ' + df['start_year'].astype(str) + ' ' + df['end_year'].astype(str) + ' Data').apply(lambda x: generate_filename(x,extension='.XPT'))
    
    dfs.append(df)

final_df = pd.concat(dfs,ignore_index=True)

alias = 'nhanes_continuous_file_metadata'
update_bq_table(final_df, alias, dataset='nhanes',bucket='nhanes', truncate = True, max_error=0, schema=None)
# Out:
# nhanes_continuous_file_metadata_20231107_203909.csv uploaded to nhanes / nhanes_continuous_file_metadata/
# Starting job b013b250-2144-4057-b9ed-cce75b93fdc2
# Job finished.
# Table Row Count 1737 rows.

# %% [markdown]
# ### Download Data and Docs to GCS

# %%
start_time = time.time()

for index, row in final_df.iterrows():
    
    if not row['doc_file_url'].endswith('.aspx'):
        try:
            r = requests.get(row['doc_file_url'],stream=True,timeout=20)
            html_content = r.content
            file_name = row['gcs_doc_filename']
            upload_blob_from_string(bucket_name = bucket_name,
                                    bucket_folder = 'docs/',
                                    file_name = file_name,
                                    blob_string = html_content,
                                    encoding='text/html')
        except Exception as ex:
            print(ex)
            print(f"Unable to upload {row['gcs_doc_filename']}")
    else:
        print(f"Skipping {row['doc_file_url']}")
    

    if not pd.isnull(row['data_file_url']) and not 'RDC' in row['data_file_url']:
        try:
            data_file_df = pd.read_sas(row['data_file_url'])
            data_file_df.to_parquet(f"gs://{bucket_name}/data/{row['gcs_data_filename'].replace('.XPT','.parquet')}")
            print(f"{row['data_file_url']} uploaded to gs://{bucket_name}/data/")
        except Exception as ex:
            print(ex)
            print(f"Unable to upload {row['gcs_data_filename']}")
            
    else:
        print(f"Skipping {row['gcs_data_filename']}")
    
print(f"Entire process took {time.time() - start_time} seconds")

# %% [markdown]
# ### Scrape Yearly Files

# %%
response = requests.get(f"https://wwwn.cdc.gov/nchs/nhanes/default.aspx")

soup = BeautifulSoup(response.text, 'lxml')

ids = [tag['id'] for tag in soup.select('div[id]')]

lis = soup.find('ul',id='nav-primary').find_all('li',{"class": "list-group-item nav-lvl2"})
ids = [el.ul['id'] for el in lis if el.ul]
ids = [i for i in ids if 'nhanes' in i]

# ['nav-group-all-continuous-nhanes',
#  'nav-group-nhanes-2021-2023',
#  'nav-group-nhanes-2017-2020',
#  'nav-group-nhanes-2019-2020']

start_time = time.time()
new_time = time.time()
dfs = []

base_url = "https://wwwn.cdc.gov"

for nhanes_id in ids:
    lis_to_scrape = soup.find('ul',id=nhanes_id).find_all('li')
    for li in lis_to_scrape:
        if 'Data' in li.text.strip() and 'Overview' not in li.text.strip() and 'Errata' not in li.text.strip() and 'Issues' not in li.text.strip() and 'Files' not in li.text.strip():
            component_text = li.text.strip().replace('All ','').replace(' Data','')
            url = base_url + li.a['href']
            dataset = nhanes_id.replace('nav-group-','')
            r = requests.get(url, timeout=20)
            soup = BeautifulSoup(r.text)
            df = scrape_nhanes_table(soup, component_text)
            
            columns = df.columns.tolist()
            df['page_component'] = component_text
            df['dataset'] = dataset
            df['last_updated'] = datetime.datetime.utcnow()
            
            if 'years' in columns:
                df['years'] = df['years'].str.strip()
                df['start_year'] = df['years'].apply(lambda x: x.split('-')[0]).astype(int)
                df['end_year'] = df['years'].apply(lambda x: x.split('-')[1]).astype(int)
            if 'doc_file' in columns:
                df['doc_file'] = df['doc_file'].str.strip()
            if 'data_file' in columns:
                df['data_file'] = df['data_file'].str.strip()
            if 'date_published' in columns:
                df['date_published'] = df['date_published'].str.strip().str.replace('Updated ','')
                df['published_date'] = pd.to_datetime(df['date_published'],format='%B %Y',errors='ignore')
            if 'data_file_name' in columns:
                if 'continuous' in dataset:
                    df['gcs_doc_filename'] = (df['data_file_name'] + ' ' + df['dataset'].astype(str) + ' ' + df['start_year'].astype(str) + ' ' + df['end_year'].astype(str) + ' Documentation').apply(lambda x: generate_filename(x,extension='.html'))
                    df['gcs_data_filename'] = (df['data_file_name'] + ' ' + df['dataset'].astype(str) + ' ' + df['start_year'].astype(str) + ' ' + df['end_year'].astype(str) + ' Data').apply(lambda x: generate_filename(x,extension='.XPT'))
                else:
                    df['gcs_doc_filename'] = (df['data_file_name'] + ' ' + df['dataset'].astype(str) + ' Documentation').apply(lambda x: generate_filename(x,extension='.html'))
                    df['gcs_data_filename'] = (df['data_file_name'] + ' ' + df['dataset'].astype(str) + ' Data').apply(lambda x: generate_filename(x,extension='.XPT'))
                    
                
            dfs.append(df)
        
yearly_df = pd.concat(dfs,ignore_index=True)

alias = 'nhanes_file_metadata'
update_bq_table(yearly_df, alias, dataset='nhanes',bucket='nhanes', truncate = True, max_error=0, schema=None)

print(f"Entire process took {time.time() - start_time} seconds")
# Out:
# nhanes_file_metadata_20231107_212632.csv uploaded to nhanes / nhanes_file_metadata/
# Starting job 07240954-8fc0-4ad3-a8e2-3d2d0f9b9c8c
# Job finished.
# Table Row Count 3578 rows.
# Entire process took 58.127763509750366 seconds

# %%
# yearly_df

# %%
start_time = time.time()
new_time = time.time()
for index, row in yearly_df.iterrows():
    
    if not row['doc_file_url'].endswith('.aspx'):
        try:
            r = requests.get(row['doc_file_url'],stream=True,timeout=20)
            html_content = r.content
            file_name = row['gcs_doc_filename']
            upload_blob_from_string(bucket_name = bucket_name,
                                    bucket_folder = row['dataset']+'/docs/',
                                    file_name = file_name,
                                    blob_string = html_content,
                                    encoding='text/html')
        except Exception as ex:
            print(ex)
            print(f"Unable to upload {row['gcs_doc_filename']}")
    else:
        print(f"Skipping {row['doc_file_url']}")
    

    if not pd.isnull(row['data_file_url']) and not 'RDC' in row['data_file_url'] and row['gcs_data_filename'].lower().endswith('.xpt'):
        try:
            data_file_df = pd.read_sas(row['data_file_url'])
            data_file_df.to_parquet(f"gs://{bucket_name}/{row['dataset']}/data/{row['gcs_data_filename'].replace('.XPT','.parquet')}")
            print(f"{row['gcs_data_filename']} uploaded to gs://{bucket_name}/{row['dataset']}/data/")
        except Exception as ex:
            print(ex)
            print(f"Unable to upload {row['gcs_data_filename']}")
            
    else:
        print(f"Skipping {row['gcs_data_filename']}")
        
    if index % 100 == 0 and index > 0:
        print(f"Last 100 datasets completed in {time.time() - new_time} seconds")
        new_time = time.time()
    
print(f"Entire process took {time.time() - start_time} seconds")
# Out:
# dietary_supplement_use_30_day_individual_dietary_supplements_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_individual_dietary_supplements_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# Last 100 datasets completed in 4.310201406478882
# dietary_supplement_use_30_day_individual_dietary_supplements_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_individual_dietary_supplements_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_file_1_supplement_counts_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_file_1_supplement_counts_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_file_1_supplement_counts_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_file_1_supplement_counts_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_file_1_supplement_counts_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_file_1_supplement_counts_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_file_1_supplement_counts_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_file_1_supplement_counts_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_file_2_participant_s_use_of_supplements_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_file_2_participant_s_use_of_supplements_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_file_2_participant_s_use_of_supplements_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_file_2_participant_s_use_of_supplements_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_file_2_participant_s_use_of_supplements_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_file_2_participant_s_use_of_supplements_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_file_2_participant_s_use_of_supplements_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_file_2_participant_s_use_of_supplements_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_individual_dietary_supplements_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_individual_dietary_supplements_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_individual_dietary_supplements_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_individual_dietary_supplements_all_continuous_nhanes_2015_2016_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_individual_dietary_supplements_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_individual_dietary_supplements_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_individual_dietary_supplements_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_individual_dietary_supplements_all_continuous_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2015_2016_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dietary_supplement_use_30_day_total_dietary_supplements_all_continuous_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# food_frequency_questionnaire_look_up_table_foodlook_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# food_frequency_questionnaire_look_up_table_foodlook_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# food_frequency_questionnaire_look_up_table_foodlook_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# food_frequency_questionnaire_look_up_table_foodlook_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# food_frequency_questionnaire_look_up_table_varlook_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# food_frequency_questionnaire_look_up_table_varlook_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# food_frequency_questionnaire_look_up_table_varlook_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# food_frequency_questionnaire_look_up_table_varlook_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# food_frequency_questionnaire_output_from_dietcalc_software_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# food_frequency_questionnaire_output_from_dietcalc_software_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# food_frequency_questionnaire_output_from_dietcalc_software_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# food_frequency_questionnaire_output_from_dietcalc_software_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# food_frequency_questionnaire_raw_questionnaire_responses_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# food_frequency_questionnaire_raw_questionnaire_responses_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# food_frequency_questionnaire_raw_questionnaire_responses_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# food_frequency_questionnaire_raw_questionnaire_responses_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# arthritis_body_measures_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# arthritis_body_measures_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_all_continuous_nhanes_2015_2016_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_all_continuous_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_acoustic_reflex_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_acoustic_reflex_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_acoustic_reflex_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_acoustic_reflex_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_acoustic_reflex_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_acoustic_reflex_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_acoustic_reflex_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_acoustic_reflex_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_acoustic_reflex_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_acoustic_reflex_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_acoustic_reflex_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_acoustic_reflex_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_acoustic_reflex_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_acoustic_reflex_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_acoustic_reflex_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_acoustic_reflex_all_continuous_nhanes_2015_2016_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_acoustic_reflex_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_acoustic_reflex_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_acoustic_reflex_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_acoustic_reflex_all_continuous_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_tympanometry_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_tympanometry_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_tympanometry_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_tympanometry_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_tympanometry_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_tympanometry_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_tympanometry_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_tympanometry_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_tympanometry_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_tympanometry_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_tympanometry_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_tympanometry_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_tympanometry_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_tympanometry_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_tympanometry_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_tympanometry_all_continuous_nhanes_2015_2016_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_tympanometry_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_tympanometry_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_tympanometry_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_tympanometry_all_continuous_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_wideband_reflectance_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_wideband_reflectance_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_wideband_reflectance_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_wideband_reflectance_all_continuous_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# audiometry_wideband_reflectance_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# audiometry_wideband_reflectance_all_continuous_nhanes_2015_2016_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# balance_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# balance_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# balance_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# balance_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# balance_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# balance_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# bioelectrical_impedance_analysis_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# bioelectrical_impedance_analysis_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# bioelectrical_impedance_analysis_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# bioelectrical_impedance_analysis_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# bioelectrical_impedance_analysis_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# bioelectrical_impedance_analysis_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# blood_pressure_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# blood_pressure_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# blood_pressure_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# blood_pressure_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# blood_pressure_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# blood_pressure_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# blood_pressure_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# blood_pressure_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# blood_pressure_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# blood_pressure_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# blood_pressure_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# blood_pressure_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# blood_pressure_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# blood_pressure_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# blood_pressure_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# blood_pressure_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# blood_pressure_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# blood_pressure_all_continuous_nhanes_2015_2016_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# blood_pressure_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# blood_pressure_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# blood_pressure_oscillometric_measurement_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# blood_pressure_oscillometric_measurement_all_continuous_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# blood_pressure_oscillometric_measurements_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# blood_pressure_oscillometric_measurements_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# body_measures_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# body_measures_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# body_measures_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# body_measures_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# body_measures_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# body_measures_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# body_measures_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# body_measures_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# body_measures_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# body_measures_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# body_measures_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# body_measures_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# body_measures_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# body_measures_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# body_measures_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# body_measures_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# body_measures_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# body_measures_all_continuous_nhanes_2015_2016_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# body_measures_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# body_measures_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# body_measures_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# body_measures_all_continuous_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# cardiovascular_fitness_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# cardiovascular_fitness_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# cardiovascular_fitness_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# cardiovascular_fitness_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# cardiovascular_fitness_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# cardiovascular_fitness_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dermatology_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dermatology_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_android_gynoid_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_android_gynoid_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_android_gynoid_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_android_gynoid_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_femur_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_femur_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_femur_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_femur_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_femur_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_femur_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# Last 100 datasets completed in 593.7082660198212
# dual_energy_x_ray_absorptiometry_spine_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_spine_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_spine_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_spine_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_spine_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_spine_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_abdominal_aortic_calcification_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Remote end closed connection without response
# Unable to upload dual_energy_x_ray_absorptiometry_abdominal_aortic_calcification_all_continuous_nhanes_2013_2014_data.XPT
# dual_energy_x_ray_absorptiometry_android_gynoid_measurements_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_android_gynoid_measurements_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_android_gynoid_measurements_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_android_gynoid_measurements_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_android_gynoid_measurements_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_android_gynoid_measurements_all_continuous_nhanes_2015_2016_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_android_gynoid_measurements_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_android_gynoid_measurements_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_femur_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_femur_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_femur_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_femur_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_femur_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_femur_all_continuous_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_frax_score_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_frax_score_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_l1_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_l1_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_l2_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_l2_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_l3_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_l3_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_l4_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_l4_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_spine_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_spine_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_spine_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_spine_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_spine_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_spine_all_continuous_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_t10_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_t10_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_t11_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_t11_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_t12_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_t12_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_t4_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_t4_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_t5_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_t5_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_t6_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_t6_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_t7_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_t7_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_t8_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_t8_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_t9_vertebrae_morphology_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_t9_vertebrae_morphology_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_vertebral_fracture_assessment_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_vertebral_fracture_assessment_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# Skipping https://wwwn.cdc.gov/Nchs/Nhanes/Dxa/Dxa.aspx
# unable to infer format of SAS file from filename: 'https://wwwn.cdc.gov/nchs/nhanes/dxa/dxa.aspx'
# Unable to upload dual_energy_x_ray_absorptiometry_whole_body_all_continuous_nhanes_1999_2006_data.XPT
# dual_energy_x_ray_absorptiometry_whole_body_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_whole_body_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_whole_body_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_whole_body_all_continuous_nhanes_2015_2016_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_whole_body_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_whole_body_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_whole_body_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_whole_body_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# dual_energy_x_ray_absorptiometry_whole_body_second_exam_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# dual_energy_x_ray_absorptiometry_whole_body_second_exam_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# exhaled_nitric_oxide_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# exhaled_nitric_oxide_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# exhaled_nitric_oxide_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# exhaled_nitric_oxide_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# exhaled_nitric_oxide_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# exhaled_nitric_oxide_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# fluorosis_clinical_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# fluorosis_clinical_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# fluorosis_clinical_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# fluorosis_clinical_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# fluorosis_clinical_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# fluorosis_clinical_all_continuous_nhanes_2015_2016_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# fluorosis_clinical_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# fluorosis_clinical_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# liver_ultrasound_transient_elastography_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# liver_ultrasound_transient_elastography_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# liver_ultrasound_transient_elastography_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# liver_ultrasound_transient_elastography_all_continuous_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# lower_extremity_disease_ankle_brachial_blood_pressure_index_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# lower_extremity_disease_ankle_brachial_blood_pressure_index_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# lower_extremity_disease_ankle_brachial_blood_pressure_index_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# lower_extremity_disease_ankle_brachial_blood_pressure_index_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# lower_extremity_disease_ankle_brachial_blood_pressure_index_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# lower_extremity_disease_ankle_brachial_blood_pressure_index_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# lower_extremity_disease_peripheral_neuropathy_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# lower_extremity_disease_peripheral_neuropathy_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# lower_extremity_disease_peripheral_neuropathy_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# lower_extremity_disease_peripheral_neuropathy_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# lower_extremity_disease_peripheral_neuropathy_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# lower_extremity_disease_peripheral_neuropathy_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# muscle_strength_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# muscle_strength_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# muscle_strength_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# muscle_strength_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# muscle_strength_grip_test_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# muscle_strength_grip_test_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# muscle_strength_grip_test_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# muscle_strength_grip_test_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# ophthalmology_frequency_doubling_technology_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# ophthalmology_frequency_doubling_technology_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# ophthalmology_frequency_doubling_technology_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# ophthalmology_frequency_doubling_technology_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# ophthalmology_retinal_imaging_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# ophthalmology_retinal_imaging_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# ophthalmology_retinal_imaging_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# ophthalmology_retinal_imaging_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_all_continuous_nhanes_2007_2008_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_all_continuous_nhanes_2005_2006_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_addendum_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_addendum_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_dentition_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_dentition_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_dentition_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_dentition_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_dentition_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_dentition_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_dentition_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_dentition_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_dentition_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_dentition_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_dentition_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_dentition_all_continuous_nhanes_2015_2016_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_dentition_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_dentition_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_dentition_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_dentition_all_continuous_nhanes_2017_2018_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_dentition_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_dentition_all_continuous_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_periodontal_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_periodontal_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_periodontal_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_periodontal_all_continuous_nhanes_2009_2010_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_periodontal_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_periodontal_all_continuous_nhanes_2011_2012_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_periodontal_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_periodontal_all_continuous_nhanes_2013_2014_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_periodontal_lower_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_periodontal_lower_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_periodontal_lower_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_periodontal_lower_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_periodontal_upper_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_periodontal_upper_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_periodontal_upper_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_periodontal_upper_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_recommendation_of_care_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_recommendation_of_care_all_continuous_nhanes_1999_2000_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_recommendation_of_care_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_recommendation_of_care_all_continuous_nhanes_2003_2004_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# oral_health_recommendation_of_care_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# oral_health_recommendation_of_care_all_continuous_nhanes_2001_2002_data.XPT uploaded to gs://nhanes/all-continuous-nhanes/data/
# ...
# Skipping mycoplasma_genitalium_urine_adult_all_continuous_nhanes_2017_2020_data.XPT
# mycoplasma_genitalium_urine_youth_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping mycoplasma_genitalium_urine_youth_all_continuous_nhanes_2017_2020_data.XPT
# occupation_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping occupation_all_continuous_nhanes_2013_2014_data.XPT
# occupation_industry_occupation_codes_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping occupation_industry_occupation_codes_all_continuous_nhanes_2007_2008_data.XPT
# occupation_industry_occupation_codes_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping occupation_industry_occupation_codes_all_continuous_nhanes_2005_2006_data.XPT
# occupation_industry_occupation_codes_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping occupation_industry_occupation_codes_all_continuous_nhanes_2009_2010_data.XPT
# occupation_industry_occupation_codes_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping occupation_industry_occupation_codes_all_continuous_nhanes_2011_2012_data.XPT
# Skipping https://wwwn.cdc.gov/Nchs/Nhanes/Omp/Default.aspx
# Skipping oral_microbiome_project_all_continuous_nhanes_2009_2012_data.XPT
# perchlorate_nitrate_thiocyanate_24_hour_urine_first_collection_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping perchlorate_nitrate_thiocyanate_24_hour_urine_first_collection_all_continuous_nhanes_2013_2014_data.XPT
# perchlorate_nitrate_thiocyanate_24_hour_urine_second_collection_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping perchlorate_nitrate_thiocyanate_24_hour_urine_second_collection_all_continuous_nhanes_2013_2014_data.XPT
# physical_activity_monitor_ambient_light_raw_data_all_continuous_nhanes_2012_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping physical_activity_monitor_ambient_light_raw_data_all_continuous_nhanes_2012_2012_data.XPT
# physical_activity_monitor_day_all_continuous_nhanes_2012_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping physical_activity_monitor_day_all_continuous_nhanes_2012_2012_data.XPT
# physical_activity_monitor_header_all_continuous_nhanes_2012_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping physical_activity_monitor_header_all_continuous_nhanes_2012_2012_data.XPT
# physical_activity_monitor_hour_all_continuous_nhanes_2012_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping physical_activity_monitor_hour_all_continuous_nhanes_2012_2012_data.XPT
# physical_activity_monitor_minute_all_continuous_nhanes_2012_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping physical_activity_monitor_minute_all_continuous_nhanes_2012_2012_data.XPT
# physical_activity_monitor_raw_data_80hz_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping physical_activity_monitor_raw_data_80hz_all_continuous_nhanes_2011_2012_data.XPT
# phytoestrogen_24_hour_urine_first_collection_all_continuous_nhanes_2014_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping phytoestrogen_24_hour_urine_first_collection_all_continuous_nhanes_2014_2014_data.XPT
# phytoestrogen_24_hour_urine_second_collection_all_continuous_nhanes_2014_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping phytoestrogen_24_hour_urine_second_collection_all_continuous_nhanes_2014_2014_data.XPT
# reproductive_health_pregnant_women_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping reproductive_health_pregnant_women_all_continuous_nhanes_2007_2008_data.XPT
# reproductive_health_pregnant_women_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping reproductive_health_pregnant_women_all_continuous_nhanes_2009_2010_data.XPT
# Last 100 datasets completed in 45.69085454940796
# reproductive_health_pregnant_women_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping reproductive_health_pregnant_women_all_continuous_nhanes_2011_2012_data.XPT
# reproductive_health_pregnant_women_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping reproductive_health_pregnant_women_all_continuous_nhanes_2013_2014_data.XPT
# reproductive_health_pregnant_women_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping reproductive_health_pregnant_women_all_continuous_nhanes_2015_2016_data.XPT
# reproductive_health_women_12_years_and_older_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping reproductive_health_women_12_years_and_older_all_continuous_nhanes_2017_2018_data.XPT
# reproductive_health_women_12_years_and_older_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping reproductive_health_women_12_years_and_older_all_continuous_nhanes_2017_2020_data.XPT
# salt_use_all_continuous_nhanes_2019_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping salt_use_all_continuous_nhanes_2019_2020_data.XPT
# second_day_lab_general_documentation_all_continuous_nhanes_2000_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping second_day_lab_general_documentation_all_continuous_nhanes_2000_2000_data.XPT
# sex_steroid_hormone_panel_serum_all_continuous_nhanes_2019_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sex_steroid_hormone_panel_serum_all_continuous_nhanes_2019_2020_data.XPT
# sexual_behavior_adult_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_adult_all_continuous_nhanes_2017_2018_data.XPT
# sexual_behavior_adult_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_adult_all_continuous_nhanes_2017_2020_data.XPT
# sexual_behavior_youth_all_continuous_nhanes_2005_2006_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_youth_all_continuous_nhanes_2005_2006_data.XPT
# sexual_behavior_youth_all_continuous_nhanes_2007_2008_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_youth_all_continuous_nhanes_2007_2008_data.XPT
# sexual_behavior_youth_all_continuous_nhanes_2009_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_youth_all_continuous_nhanes_2009_2010_data.XPT
# sexual_behavior_youth_all_continuous_nhanes_2011_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_youth_all_continuous_nhanes_2011_2012_data.XPT
# sexual_behavior_youth_all_continuous_nhanes_1999_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_youth_all_continuous_nhanes_1999_2000_data.XPT
# sexual_behavior_youth_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_youth_all_continuous_nhanes_2013_2014_data.XPT
# sexual_behavior_youth_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_youth_all_continuous_nhanes_2015_2016_data.XPT
# sexual_behavior_youth_all_continuous_nhanes_2001_2002_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_youth_all_continuous_nhanes_2001_2002_data.XPT
# sexual_behavior_youth_all_continuous_nhanes_2003_2004_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_youth_all_continuous_nhanes_2003_2004_data.XPT
# sexual_behavior_youth_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_youth_all_continuous_nhanes_2017_2018_data.XPT
# sexual_behavior_youth_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sexual_behavior_youth_all_continuous_nhanes_2017_2020_data.XPT
# sodium_potassium_chloride_casual_urine_all_continuous_nhanes_2010_2010_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping sodium_potassium_chloride_casual_urine_all_continuous_nhanes_2010_2010_data.XPT
# standard_biochemistry_profile_hormones_second_exam_all_continuous_nhanes_2000_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping standard_biochemistry_profile_hormones_second_exam_all_continuous_nhanes_2000_2000_data.XPT
# standing_balance_all_continuous_nhanes_2019_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping standing_balance_all_continuous_nhanes_2019_2020_data.XPT
# taste_smell_all_continuous_nhanes_2012_2012_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping taste_smell_all_continuous_nhanes_2012_2012_data.XPT
# thyroid_profile_serum_all_continuous_nhanes_2019_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping thyroid_profile_serum_all_continuous_nhanes_2019_2020_data.XPT
# trichomonas_urine_adult_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping trichomonas_urine_adult_all_continuous_nhanes_2017_2018_data.XPT
# trichomonas_urine_adult_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping trichomonas_urine_adult_all_continuous_nhanes_2017_2020_data.XPT
# trichomonas_urine_youth_all_continuous_nhanes_2015_2016_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping trichomonas_urine_youth_all_continuous_nhanes_2015_2016_data.XPT
# trichomonas_urine_youth_all_continuous_nhanes_2017_2018_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping trichomonas_urine_youth_all_continuous_nhanes_2017_2018_data.XPT
# trichomonas_urine_youth_all_continuous_nhanes_2017_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping trichomonas_urine_youth_all_continuous_nhanes_2017_2020_data.XPT
# trichomonas_urine_youth_all_continuous_nhanes_2013_2014_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping trichomonas_urine_youth_all_continuous_nhanes_2013_2014_data.XPT
# tuberculosis_quantiferon_tb_gold_plus_all_continuous_nhanes_2019_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping tuberculosis_quantiferon_tb_gold_plus_all_continuous_nhanes_2019_2020_data.XPT
# vitamin_a_vitamin_e_second_exam_all_continuous_nhanes_2000_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping vitamin_a_vitamin_e_second_exam_all_continuous_nhanes_2000_2000_data.XPT
# vitamin_d_second_exam_all_continuous_nhanes_2000_2000_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping vitamin_d_second_exam_all_continuous_nhanes_2000_2000_data.XPT
# volatile_organic_compounds_a_pinene_blood_all_continuous_nhanes_2019_2020_documentation.html uploaded to nhanes / all-continuous-nhanes/docs/
# Skipping volatile_organic_compounds_a_pinene_blood_all_continuous_nhanes_2019_2020_data.XPT
# demographic_variables_and_sample_weights_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# demographic_variables_and_sample_weights_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_interview_individual_foods_first_day_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_interview_individual_foods_first_day_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_interview_individual_foods_second_day_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_interview_individual_foods_second_day_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_interview_total_nutrient_intakes_first_day_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_interview_total_nutrient_intakes_first_day_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_interview_total_nutrient_intakes_second_day_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_interview_total_nutrient_intakes_second_day_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_interview_technical_support_file_food_codes_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_interview_technical_support_file_food_codes_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_supplement_database_blend_information_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_supplement_database_blend_information_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_supplement_database_ingredient_information_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_supplement_database_ingredient_information_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_supplement_database_product_information_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_supplement_database_product_information_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_supplement_use_24_hour_individual_dietary_supplements_first_day_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_supplement_use_24_hour_individual_dietary_supplements_first_day_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_supplement_use_24_hour_individual_dietary_supplements_second_day_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_supplement_use_24_hour_individual_dietary_supplements_second_day_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_supplement_use_24_hour_total_dietary_supplements_first_day_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_supplement_use_24_hour_total_dietary_supplements_first_day_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_supplement_use_24_hour_total_dietary_supplements_second_day_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_supplement_use_24_hour_total_dietary_supplements_second_day_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_supplement_use_30_day_individual_dietary_supplements_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_supplement_use_30_day_individual_dietary_supplements_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# dietary_supplement_use_30_day_total_dietary_supplements_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# dietary_supplement_use_30_day_total_dietary_supplements_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# audiometry_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/
# audiometry_nhanes_2017_2020_data.XPT uploaded to gs://nhanes/nhanes-2017-2020/data/
# audiometry_acoustic_reflex_nhanes_2017_2020_documentation.html uploaded to nhanes / nhanes-2017-2020/docs/

# %%
# len(yearly_df)

# %%
# table = soup.find('table',id='GridView1')

# headers = []
# for i in table.find_all('th'):
#     title = i.text
#     headers.append(title)

# base_url = "https://wwwn.cdc.gov"

# data = []

# for j in table.find_all('tr')[1:]:
#     row_data = j.find_all('td')
#     row = [i.text for i in row_data] + [base_url + i.a['href'] for i in row_data if i.find('a')]
#     data.append(row)
    
# if len(data[0]) == len(headers) + 2:
#     headers = ['_'.join(h.lower().split()) for h in headers] + ['doc_file_url','data_file_url']
# elif len(data[0]) == len(headers) + 1:
#     headers = ['_'.join(h.lower().split()) for h in headers] + ['doc_file_url']
# else:
#     headers = ['_'.join(h.lower().split()) for h in headers]

# df = pd.DataFrame(columns = headers,data=data)

# %%
# table

# %%
# final_df[index:][final_df['doc_file_url'].str.contains('.aspx')]
