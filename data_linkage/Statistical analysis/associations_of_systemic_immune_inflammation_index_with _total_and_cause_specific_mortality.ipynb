# %% [markdown]
# ### Physical activity attenuates the associations of systemic immune-inflammation index with total and cause-specific mortality among middle-aged and older populations
# https://www.nature.com/articles/s41598-021-91324-x#Sec6

# %% [markdown]
# #### Results
# Subjects in the high SII subgroup had increased risks of total, CVD, cancer, and other causes mortality
# [HR (95%CI) = 1.38 (1.27–1.49), 1.33 (1.11–1.59), 1.22 (1.04–1.45) and 1.47 (1.32–1.63), respectively]

# %% [markdown]
# #### Study populations
# In the NHANES 1999–2014, after excluding individuals who did not take health examination (n = 1487), without mortality data (n = 38), and without information of related blood cells count (n = 1318), a total of 25,761 participants aged ≥ 40 years old were included because most deaths occurred in these adults

# %% [markdown]
# ...
# ...

# %%
pip install google-cloud-bigquery

# %%
pip install db-dtypes
# Out:
# Collecting db-dtypes
#   Obtaining dependency information for db-dtypes from https://files.pythonhosted.org/packages/4e/5c/72b74daf6655db6f6afc2b3bc44359c7953004ef4630325a3ae0efc50872/db_dtypes-1.2.0-py2.py3-none-any.whl.metadata
#   Downloading db_dtypes-1.2.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging>=17.0 in c:\users\samuel donkor\anaconda3\lib\site-packages (from db-dtypes) (23.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\samuel donkor\anaconda3\lib\site-packages (from db-dtypes) (2.0.3)
# Requirement already satisfied: pyarrow>=3.0.0 in c:\users\samuel donkor\anaconda3\lib\site-packages (from db-dtypes) (11.0.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\samuel donkor\anaconda3\lib\site-packages (from db-dtypes) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\samuel donkor\anaconda3\lib\site-packages (from pandas>=0.24.2->db-dtypes) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samuel donkor\anaconda3\lib\site-packages (from pandas>=0.24.2->db-dtypes) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\samuel donkor\anaconda3\lib\site-packages (from pandas>=0.24.2->db-dtypes) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\samuel donkor\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->db-dtypes) (1.16.0)
# Downloading db_dtypes-1.2.0-py2.py3-none-any.whl (14 kB)
# Installing collected packages: db-dtypes
# Successfully installed db-dtypes-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "nhanesgcp-93d0f7365fdc.json"

# %%
from google.cloud import bigquery
client = bigquery.Client()

# %%
query = """
WITH SmokingData AS (
    SELECT
        respondent_sequence_number,
        smoked_at_least_100_cigarettes_in_life
    FROM
        `nhanesgcp.dbt.smoking_cigarette_use_questionnaire`
),
AlcoholData AS (
    SELECT
        respondent_sequence_number,
        had_at_least_12_alcohol_drinks_1_yr
    FROM
        `nhanesgcp.dbt.alcohol_use_questionnaire`
),
SmokingStatus AS (
    SELECT
        respondent_sequence_number,
        CASE
            WHEN smoked_at_least_100_cigarettes_in_life IS NULL THEN NULL
            WHEN smoked_at_least_100_cigarettes_in_life = 'Yes' THEN 'Smoker'
            ELSE 'Non-Smoker'
        END AS smoking_status
    FROM
        SmokingData
),
AlcoholDrinkingStatus AS (
    SELECT
        respondent_sequence_number,
        CASE
            WHEN had_at_least_12_alcohol_drinks_1_yr IS NULL THEN NULL
            WHEN had_at_least_12_alcohol_drinks_1_yr = 'Yes' THEN 'Drinker'
            ELSE 'Non-Drinker'
        END AS alcohol_drinking_status
    FROM
        AlcoholData
),
PhysicalActivityData AS (
    SELECT
        respondent_sequence_number,
        COALESCE(SUM(CASE
                WHEN vigorous_activity_over_past_30_days = 'Yes' THEN of_times_past_30_days * how_long_each_time_minutes
                ELSE 0
            END), 0) +
        COALESCE(SUM(CASE
                WHEN moderate_activity_over_past_30_days = 'Yes' THEN of_times_past_30_days * how_long_each_time_minutes
                ELSE 0
            END), 0) AS total_activity_duration_minutes
    FROM
        `nhanesgcp.dbt.physical_activity_questionnaire`
    GROUP BY
        respondent_sequence_number
),
SII_Calculation AS (
    SELECT 
        respondent_sequence_number,
        (segmented_neutrophils_num_1000_cell_ul * platelet_count_1000_cells_ul) / lymphocyte_number_1000_cells_ul AS SII
    FROM 
        `nhanesgcp.dbt.complete_blood_count_with_5_part_differential_whole_blood_laboratory`
),
Filtered_Demographics AS (
    SELECT 
        respondent_sequence_number,
        age_in_years_at_screening AS age,
        gender,
        race_hispanic_origin AS race
    FROM 
        `nhanesgcp.dbt.demographic_variables_sample_weights_demographics`
    WHERE 
        end_year <= 2015
        AND 
        CAST(age_in_years_at_screening AS INT64) >= 40
),
BodyMeasurements AS (
    SELECT 
        respondent_sequence_number,
        weight_kg,
        standing_height_cm,
        weight_kg / (standing_height_cm / 100) AS bmi
    FROM 
        `nhanesgcp.dbt.body_measures_examination`
),
PhysicalActivityStatus AS (
    SELECT
        respondent_sequence_number,
        CASE
            WHEN COALESCE(total_activity_duration_minutes, 0) >= 150 THEN 'Physically Active'
            ELSE 'Physically Inactive'
        END AS physical_activity_status
    FROM
        PhysicalActivityData
),
MortalityData AS (
    SELECT
        respondent_sequence_number,
        ucod_leading,
        mort_stat,
        permth_exm
    FROM
        `nhanesgcp.nhanes_mort_1999_2018.nhanes_mort`
),
SII_Stats AS (
    SELECT
        APPROX_QUANTILES(SII, 4) AS quartiles
    FROM
        SII_Calculation
),
SII_Groups AS (
    SELECT
        SII_Calculation.*,
        CASE
            WHEN SII IS NULL THEN NULL
            WHEN SII <= (SELECT quartiles[OFFSET(1)] FROM SII_Stats) THEN 'Low'
            WHEN SII <= (SELECT quartiles[OFFSET(2)] FROM SII_Stats) THEN 'Middle'
            ELSE 'High'
        END AS SII_Group
    FROM
        SII_Calculation
    CROSS JOIN
        SII_Stats
)
SELECT 
    fd.respondent_sequence_number,
    fd.age,
    fd.gender,
    fd.race,
    bm.bmi,
    sii.SII,
    ss.smoking_status,
    ads.alcohol_drinking_status,
    pa.total_activity_duration_minutes AS physical_activity_duration_minutes,
    pas.physical_activity_status,
    md.ucod_leading,
    md.mort_stat,
    md.permth_exm,
    sg.SII_Group
FROM 
    Filtered_Demographics fd
LEFT JOIN 
    BodyMeasurements bm ON fd.respondent_sequence_number = bm.respondent_sequence_number
LEFT JOIN 
    SII_Calculation sii ON fd.respondent_sequence_number = sii.respondent_sequence_number
LEFT JOIN 
    SmokingStatus ss ON fd.respondent_sequence_number = ss.respondent_sequence_number
LEFT JOIN 
    AlcoholDrinkingStatus ads ON fd.respondent_sequence_number = ads.respondent_sequence_number
LEFT JOIN 
    SmokingData smoking ON fd.respondent_sequence_number = smoking.respondent_sequence_number
LEFT JOIN 
    AlcoholData alcohol ON fd.respondent_sequence_number = alcohol.respondent_sequence_number
LEFT JOIN
    PhysicalActivityData pa ON fd.respondent_sequence_number = pa.respondent_sequence_number
LEFT JOIN
    PhysicalActivityStatus pas ON fd.respondent_sequence_number = pas.respondent_sequence_number
LEFT JOIN
    MortalityData md ON fd.respondent_sequence_number = md.respondent_sequence_number
LEFT JOIN
    SII_Groups sg ON fd.respondent_sequence_number = sg.respondent_sequence_number
WHERE
    sii.SII IS NOT NULL
ORDER BY
    fd.respondent_sequence_number;

"""

# %%
df = client.query(query).to_dataframe()

# %%
df.head(50)
# Out:
#     respondent_sequence_number   age  gender  \
# 0                            2  77.0    Male
# 1                            5  49.0    Male
# 2                            7  59.0  Female
# 3                           10  43.0    Male
# 4                           13  70.0    Male
# 5                           14  81.0    Male
# 6                           16  85.0  Female
# 7                           24  53.0  Female
# 8                           25  42.0  Female
# 9                           29  62.0    Male
# 10                          33  46.0    Male
# 11                          40  68.0  Female
# 12                          46  85.0  Female
# 13                          55  61.0  Female
# 14                          59  70.0    Male
# 15                          64  63.0  Female
# 16                          83  60.0  Female
# 17                          86  63.0  Female
# 18                          93  63.0  Female
# 19                          94  61.0  Female
# 20                         101  52.0    Male
# 21                         102  41.0  Female
# 22                         115  59.0  Female
# 23                         118  85.0    Male
# 24                         122  64.0    Male
# 25                         123  76.0    Male
# 26                         129  63.0  Female
# 27                         130  59.0    Male
# 28                         131  56.0    Male
# 29                         132  41.0  Female
# 30                         136  53.0    Male
# 31                         147  43.0    Male
# 32                         149  40.0  Female
# 33                         150  65.0    Male
# 34                         151  84.0    Male
# 35                         160  62.0    Male
# 36                         162  63.0    Male
# 37                         163  63.0  Female
# 38                         164  51.0    Male
# 39                         166  41.0    Male
# 40                         172  41.0    Male
# 41                         173  82.0  Female
# 42                         177  55.0  Female
# 43                         178  60.0  Female
# 44                         187  71.0  Female
# 45                         190  65.0    Male
# 46                         191  69.0    Male
# 47                         194  44.0  Female
# 48                         197  74.0    Male
# 49                         198  49.0  Female
#
#                                    race        bmi          SII  \
# 0                    Non-Hispanic White  43.333333   682.125000
# 1                    Non-Hispanic White  51.878856   294.500000
# 2                    Non-Hispanic Black  47.882136   222.782609
# 3                    Non-Hispanic Black  58.811152   175.789474
# 4                      Mexican American  40.329740  1459.200000
# 5                    Non-Hispanic White  45.427196   337.777778
# 6                    Non-Hispanic Black  28.779473   500.571429
# 7                    Non-Hispanic White  42.570037   438.351351
# 8                    Non-Hispanic White  62.687463   531.423077
# 9                    Non-Hispanic White  64.608348  4930.000000
# 10                     Mexican American  63.215103   508.869565
# 11                     Mexican American  45.070423   552.485714
# 12                   Non-Hispanic Black  37.017995   246.250000
# 13                       Other Hispanic  40.896200   234.300000
# 14                     Mexican American  52.827051  1077.333333
# 15                   Non-Hispanic Black  33.312846   836.111111
# 16                   Non-Hispanic Black  53.933254   329.000000
# 17                   Non-Hispanic White  52.606061   352.444444
# 18  Other Race - Including Multi-Racial  36.466165   502.153846
# 19                   Non-Hispanic Black  56.410256   333.925926
# 20                     Mexican American  40.603248   370.000000
# 21  Other Race - Including Multi-Racial  40.850515   422.736842
# 22                   Non-Hispanic White  34.386391  1248.058824
# 23                   Non-Hispanic White  53.977273   353.571429
# 24                   Non-Hispanic White  58.766419   622.095238
# 25                   Non-Hispanic White  65.720646   339.888889
# 26                   Non-Hispanic White  63.039514   992.250000
# 27                   Non-Hispanic White  44.769141   397.375000
# 28                   Non-Hispanic White  48.676957   439.300000
# 29                   Non-Hispanic White  72.453704  1200.000000
# 30                     Mexican American  73.724792   460.375000
# 31                     Mexican American  41.252194  1353.571429
# 32                       Other Hispanic  40.730897   864.800000
# 33                   Non-Hispanic White  54.744106   789.444444
# 34                   Non-Hispanic White  45.755814   473.000000
# 35                   Non-Hispanic White        NaN   555.333333
# 36                     Mexican American  43.858633   869.833333
# 37                     Mexican American  39.759798   297.000000
# 38                   Non-Hispanic White  53.284258   630.111111
# 39                     Mexican American  46.867322   471.078947
# 40                   Non-Hispanic Black  64.591029   450.666667
# 41                   Non-Hispanic White  41.923319   451.555556
# 42                   Non-Hispanic White  56.540881   620.714286
# 43                   Non-Hispanic Black  52.881152   612.000000
# 44                   Non-Hispanic Black  41.995074   801.368421
# 45                   Non-Hispanic Black  39.244186   389.111111
# 46                     Mexican American  39.676113   408.500000
# 47                     Mexican American  47.433511   520.235294
# 48                       Other Hispanic  47.853463   211.259259
# 49                       Other Hispanic  44.972239   231.880000
#
#    smoking_status alcohol_drinking_status  physical_activity_duration_minutes  \
# 0            None                    None                                 0.0
# 1            None                    None                              2040.0
# 2            None                    None                                12.0
# 3            None                    None                                 0.0
# 4            None                    None                                 0.0
# 5            None                    None                              1080.0
# 6            None                    None                               780.0
# 7            None                    None                                 0.0
# 8            None                    None                                 0.0
# 9            None                    None                                 0.0
# 10           None                    None                                 0.0
# 11           None                    None                                 0.0
# 12           None                    None                                 0.0
# 13           None                    None                                 0.0
# 14           None                    None                                 0.0
# 15           None                    None                                 0.0
# 16           None                    None                               720.0
# 17           None                    None                                 0.0
# 18           None                    None                              1560.0
# 19           None                    None                                 0.0
# 20           None                    None                               270.0
# 21           None                    None                                 0.0
# 22           None                    None                                 0.0
# 23           None                    None                                 0.0
# 24           None                    None                                 0.0
# 25           None                    None                                 0.0
# 26           None                    None                               135.0
# 27           None                    None                               480.0
# 28           None                    None                                 0.0
# 29           None                    None                               130.0
# 30           None                    None                                 0.0
# 31           None                    None                                 0.0
# 32           None                    None                                 0.0
# 33           None                    None                                 0.0
# 34           None                    None                                 0.0
# 35           None                    None                                 0.0
# 36           None                    None                                 0.0
# 37           None                    None                                 0.0
# 38           None                    None                               960.0
# 39           None                    None                                 0.0
# 40           None                    None                               480.0
# 41           None                    None                                30.0
# 42           None                    None                               450.0
# 43           None                    None                                 0.0
# 44           None                    None                                 0.0
# 45           None                    None                               480.0
# 46           None                    None                                 0.0
# 47           None                    None                                 0.0
# 48           None                    None                                 0.0
# 49           None                    None                                 0.0
#
#    physical_activity_status  ucod_leading  mort_stat  permth_exm SII_Group
# 0       Physically Inactive           6.0          1         177      High
# 1         Physically Active           NaN          0         244       Low
# 2       Physically Inactive           NaN          0         236       Low
# 3       Physically Inactive           1.0          1         231       Low
# 4       Physically Inactive           1.0          1          16      High
# 5         Physically Active           3.0          1         136    Middle
# 6         Physically Active           2.0          1          62      High
# 7       Physically Inactive           2.0          1         160    Middle
# 8       Physically Inactive          10.0          1         142      High
# 9       Physically Inactive           3.0          1          26      High
# 10      Physically Inactive           NaN          0         244      High
# 11      Physically Inactive           1.0          1         117      High
# 12      Physically Inactive           1.0          1          21       Low
# 13      Physically Inactive           NaN          0         243       Low
# 14      Physically Inactive           2.0          1         214      High
# 15      Physically Inactive           2.0          1         106      High
# 16        Physically Active           1.0          1         232    Middle
# 17      Physically Inactive           NaN          0         236    Middle
# 18        Physically Active           NaN          0         242      High
# 19      Physically Inactive           NaN          0         243    Middle
# 20        Physically Active           NaN          0         240    Middle
# 21      Physically Inactive           NaN          0         228    Middle
# 22      Physically Inactive           NaN          0         229      High
# 23      Physically Inactive           1.0          1          41    Middle
# 24      Physically Inactive           NaN          0         241      High
# 25      Physically Inactive           2.0          1          57    Middle
# 26      Physically Inactive           NaN          0         246      High
# 27        Physically Active           NaN          0         247    Middle
# 28      Physically Inactive           NaN          0         229    Middle
# 29      Physically Inactive           NaN          0         245      High
# 30      Physically Inactive          10.0          1          23      High
# 31      Physically Inactive           NaN          0         244      High
# 32      Physically Inactive           NaN          0         243      High
# 33      Physically Inactive           6.0          1          98      High
# 34      Physically Inactive           2.0          1         119      High
# 35      Physically Inactive           NaN          0         245      High
# 36      Physically Inactive           3.0          1         193      High
# 37      Physically Inactive           NaN          0         237       Low
# 38        Physically Active           NaN          0         242      High
# 39      Physically Inactive           NaN          0         229      High
# 40        Physically Active          10.0          1         210      High
# 41      Physically Inactive           NaN          0         242      High
# 42        Physically Active           NaN          0         244      High
# 43      Physically Inactive           NaN          0         239      High
# 44      Physically Inactive           1.0          1          67      High
# 45        Physically Active           NaN          0         244    Middle
# 46      Physically Inactive           2.0          1          76    Middle
# 47      Physically Inactive           NaN          0         239      High
# 48      Physically Inactive           NaN          0         248       Low
# 49      Physically Inactive           NaN          0         239       Low

# %%
df
# Out:
#        respondent_sequence_number   age  gender  \
# 0                               2  77.0    Male
# 1                               5  49.0    Male
# 2                               7  59.0  Female
# 3                              10  43.0    Male
# 4                              13  70.0    Male
# ...                           ...   ...     ...
# 22220                       71902  67.0  Female
# 22221                       71907  80.0    Male
# 22222                       71908  66.0  Female
# 22223                       71912  40.0    Male
# 22224                       71915  60.0    Male
#
#                                       race        bmi          SII  \
# 0                       Non-Hispanic White  43.333333   682.125000
# 1                       Non-Hispanic White  51.878856   294.500000
# 2                       Non-Hispanic Black  47.882136   222.782609
# 3                       Non-Hispanic Black  58.811152   175.789474
# 4                         Mexican American  40.329740  1459.200000
# ...                                    ...        ...          ...
# 22220  Other Race - Including Multi-Racial  58.743169   733.700000
# 22221                   Non-Hispanic White  40.763968   291.214286
# 22222                   Non-Hispanic White  55.786164   352.444444
# 22223                   Non-Hispanic White  49.520587   617.615385
# 22224                   Non-Hispanic White  46.445498  1361.176471
#
#       smoking_status alcohol_drinking_status  \
# 0               None                    None
# 1               None                    None
# 2               None                    None
# 3               None                    None
# 4               None                    None
# ...              ...                     ...
# 22220     Non-Smoker                 Drinker
# 22221     Non-Smoker                 Drinker
# 22222     Non-Smoker             Non-Drinker
# 22223         Smoker                 Drinker
# 22224     Non-Smoker                 Drinker
#
#        physical_activity_duration_minutes physical_activity_status  \
# 0                                     0.0      Physically Inactive
# 1                                  2040.0        Physically Active
# 2                                    12.0      Physically Inactive
# 3                                     0.0      Physically Inactive
# 4                                     0.0      Physically Inactive
# ...                                   ...                      ...
# 22220                                 0.0      Physically Inactive
# 22221                                 0.0      Physically Inactive
# 22222                                 0.0      Physically Inactive
# 22223                                 0.0      Physically Inactive
# 22224                                 0.0      Physically Inactive
#
#        ucod_leading  mort_stat  permth_exm SII_Group
# 0               6.0          1         177      High
# 1               NaN          0         244       Low
# 2               NaN          0         236       Low
# 3               1.0          1         231       Low
# 4               1.0          1          16      High
# ...             ...        ...         ...       ...
# 22220           1.0          1          94      High
# 22221           4.0          1          84       Low
# 22222           NaN          0         103    Middle
# 22223           NaN          0          95      High
# 22224           2.0          1          77      High
#
# [22225 rows x 14 columns]

# %%
cph = CoxPHFitter()


# columns_to_exclude = ['age','gender','race','bmi','smoked_at_least_100_cigarettes_in_life','had_at_least_12_alcohol_drinks_1_yr','smoking_status','alcohol_drinking_status','physical_activity_duration_minutes']
# df = df.drop(columns=columns_to_exclude)

# df_cleaned = df.dropna()
df_cleaned['SII_Group'] = pd.Categorical(df_cleaned['SII_Group'], categories=['Low', 'Middle', 'High'], ordered=True)

cph.fit(df_cleaned, duration_col='permth_exm', event_col='mort_stat', formula="SII_Group")
# Out:
# <lifelines.CoxPHFitter: fitted with 2643 total observations, 0 right-censored observations>

# %%
 cph.summary
# Out:
#                          coef  exp(coef)  se(coef)  coef lower 95%  \
# covariate
# SII_Group[T.Middle] -0.093138   0.911068  0.064772       -0.220089
# SII_Group[T.High]   -0.056702   0.944876  0.053151       -0.160876
#
#                      coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%  \
# covariate
# SII_Group[T.Middle]        0.033814             0.802447             1.034392
# SII_Group[T.High]          0.047472             0.851397             1.048617
#
#                      cmp to         z         p  -log2(p)
# covariate
# SII_Group[T.Middle]     0.0 -1.437924  0.150456  2.732590
# SII_Group[T.High]       0.0 -1.066808  0.286059  1.805617

# %%
# df_cleaned = df_cleaned.dropna(subset=['ucod_leading'])
cph.fit(df_cleaned, duration_col='permth_exm', event_col='mort_stat',  formula="SII_Group")

hazard_ratios = cph.summary['exp(coef)']
print("Hazard Ratios:")
print(hazard_ratios)

cph.summary
# Out:
# Hazard Ratios:
# covariate
# SII_Group[T.Middle]    0.911068
# SII_Group[T.High]      0.944876
# Name: exp(coef), dtype: float64
#                          coef  exp(coef)  se(coef)  coef lower 95%  \
# covariate
# SII_Group[T.Middle] -0.093138   0.911068  0.064772       -0.220089
# SII_Group[T.High]   -0.056702   0.944876  0.053151       -0.160876
#
#                      coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%  \
# covariate
# SII_Group[T.Middle]        0.033814             0.802447             1.034392
# SII_Group[T.High]          0.047472             0.851397             1.048617
#
#                      cmp to         z         p  -log2(p)
# covariate
# SII_Group[T.Middle]     0.0 -1.437924  0.150456  2.732590
# SII_Group[T.High]       0.0 -1.066808  0.286059  1.805617

# %%
cause_specific_df = df_cleaned[df_cleaned['ucod_leading'] == 1]
cph.fit(cause_specific_df, duration_col='permth_exm', event_col='mort_stat', formula="SII_Group")
hazard_ratios = cph.summary['exp(coef)']
print("Hazard Ratios for Cause-Specific Mortality (Other causes):")
print(hazard_ratios)
cph.summary
# Out:
# Hazard Ratios for Cause-Specific Mortality (Other causes):
# covariate
# SII_Group[T.Middle]    1.024043
# SII_Group[T.High]      1.067418
# Name: exp(coef), dtype: float64
#                          coef  exp(coef)  se(coef)  coef lower 95%  \
# covariate
# SII_Group[T.Middle]  0.023758   1.024043  0.138296       -0.247298
# SII_Group[T.High]    0.065243   1.067418  0.113292       -0.156806
#
#                      coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%  \
# covariate
# SII_Group[T.Middle]        0.294814             0.780908             1.342876
# SII_Group[T.High]          0.287292             0.854870             1.332813
#
#                      cmp to         z         p  -log2(p)
# covariate
# SII_Group[T.Middle]     0.0  0.171791  0.863602  0.211562
# SII_Group[T.High]       0.0  0.575883  0.564694  0.824458
